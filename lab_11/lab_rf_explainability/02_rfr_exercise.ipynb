# %% [markdown]
# - RFR currency regression
# - Load currency pair data 'data/forex-1year-high.csv'
# - Choose a target variable as 'high_eurusd' or 'high_audusd' (compare)
# - Remove them from the training features :)
# - Divide time series: first window 80% train, last 20% window test
# - Create RandomForestRegressor, predict the variable
# - Compute MAE (Mean Absolute Error)
# - Plot: on the first subplot: the true time series and its prediction, on the second subplot: error -> plt.subplot(2,1,1)
# - Compute the mean MAE
# - Bonus: compare with KNeighborsRegressor

# %%
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

df = pd.read_csv('data/forex-1year-high.csv',index_col='timestamp')
df.index = pd.to_datetime(df.index)

df.plot()
plt.axvspan(df.index[0], df.index[int(len(df)*0.8)], color='green', alpha=0.3)
plt.axvspan(df.index[int(len(df)*0.8)],df.index[-1], color='blue', alpha=0.3)
plt.show()
